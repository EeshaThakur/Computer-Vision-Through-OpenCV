# %%
# Import OpenCV library
import cv2

# Read the image from the current folder
# Replace "flower.jpg" with your image file name
img = cv2.imread("image.jpg")

# Print the image dimensions (height, width, channels)
# shape[0] = Height
# shape[1] = Width
# shape[2] = Number of color channels (usually 3 for RGB/BGR)
print(img.shape)
# Out:
# (431, 687, 3)
